-- %% [markdown]
-- # Customer Master

-- %%
select * from silverzone.logsourcefilesprocessed where sourcefilename in ('ZHCUSTOMR.csv','ZBWI05225_CUSTOMER_AGN_CON.csv')
--and LogFileStatus = 'Succeeded'
--and FileNameUUID = '76c0e820-31dc-4eaa-88fb-3511561f3338'
order by CreatedDt desc --limit 2

-- %%
select Filenameuuid,COUNT(*) from silverzone.dimcustomermaster where FileNameUUID in ('76c0e820-31dc-4eaa-88fb-3511561f3338','bf3c93a6-9d69-48fc-9ade-3815eb0069a4')
group by FileNameUUID

-- %%
select * from 
(
SELECT 
AccountID,count(1) as dup_count
FROM Silverzone.dimcustomermaster
group by AccountID
having count(1)>1
)

-- %%
select * from silverzone.dimcustomermaster where CreatedBy <> 'InitialDataLoad'
--and ProcessedByNm = 'ZHCUSTOMR.csv'
and ProcessedByNm = 'ZBWI05225_CUSTOMER_AGN_CON.csv'

-- %% [markdown]
-- #Product Hierarchy

-- %%
select * from silverzone.logsourcefilesprocessed where sourcefilename like '%PROD%'
and LogFileStatus = 'Succeeded'
and SourceFileName = '20230512_PROD_CLASS.TXT'
order by CreatedDt desc limit 1

-- %%
select count(1) as target_count from Silverzone.dimproducthierarchy

-- %%
select ProductCd,count(1) 
from Silverzone.dimproducthierarchy 
group by ProductCd
having count(1)> 1

-- %%
select * from silverzone.DIMProductHierarchy where UpdatedBy <> 'InitialDataLoad'
and FileNameUUID = '7be302b4-6dac-47ae-9a44-1814813c3b7f'
and ProductCd = 'SC17043'

-- %% [markdown]
-- # Product Hierarchy New File check

-- %%
select * from silverzone.logsourcefilesprocessed where sourcefilename like 'ZBWI05306%'
and LogFileStatus = 'Succeeded'
--and SourceFileName = '20230512_PROD_CLASS.TXT'
order by CreatedDt desc limit 1

-- %%
select * from silverzone.DIMProductHierarchy where UpdatedBy <> 'InitialDataLoad'
and FileNameUUID = '4e4b9c6b-0e7a-44f6-812f-ccf0346eaa5b'
and ProductCd = 'CS-309558'

-- %% [markdown]
-- # Equipment Master

-- %%
select * from silverzone.logsourcefilesprocessed where sourcefilename like '%EQUIP%'
and CreatedBy <> 'InitialDataLoad'
and LogFileStatus = 'Succeeded'
order by CreatedDt desc

-- %%
select 
count(1) 
from silverzone.DIMEquipmentMaster
where FileNameUUID = '62992985-b456-47d4-97ee-64a2aef86061'

-- %%
select 
EquipmentKey, SerialNumberNbr, ChangedOnDateKey, LoadDateOrderNbr
, count(*)
FROM
silverzone.DIMEquipmentMaster
GROUP BY EquipmentKey, ChangedOnDateKey, LoadDateOrderNbr, SerialNumberNbr
having count(*) > 1

-- %%
select * from silverzone.dimproducthierarchy where ProductCd = 'BRZ-AP2-160-000_R'

-- %%
select * from silverzone.dimequipmentmaster where 
FileNameUUID = '62992985-b456-47d4-97ee-64a2aef86061' 
and EquipmentKey = '000000000031668467'
order by LoadDateOrderNbr asc

-- %% [markdown]
-- #Equipment master new file check

-- %%
select * from silverzone.logsourcefilesprocessed where sourcefilename like '%ZBWI05226_AGN_CON%'
and CreatedBy <> 'InitialDataLoad'
and LogFileStatus = 'Succeeded'
order by CreatedDt desc

-- %%
select * from silverzone.dimproducthierarchy where ProductCd = 'BRZ-CD4-140-024'

-- %%
select * from silverzone.dimequipmentmaster where 
FileNameUUID = 'fd8bde2c-0e0f-4194-a687-3f6803eaa2b9' 
and 
EquipmentKey = '000000000011046257'
order by LoadDateOrderNbr ascselect 
* 
from 
silverzone.logsourcefilesprocessed 
where SourceFileName = 'DeviceTwin_20230513.json'
and LogFileStatus = 'Succeeded'
order by CreatedDt desc

-- %% [markdown]
-- # PDM Alignment

-- %%
select 
* 
from 
silverzone.logsourcefilesprocessed 
where SourceFileName = 'CoolConnect_Alignment_20230513.csv'
and LogFileStatus = 'Succeeded'
order by CreatedDt desc

-- %%
SELECT count(1) as target_row_count FROM Silverzone.DIMAlignmentData where FileNameUUID = 'f9812234-5a32-4bb3-94af-8209899db494'

-- %%
select 
AccountID, 
AccountAddressId,
count(*) as dup_cnt
from Silverzone.dimalignmentdata
group by AccountID
, AccountAddressId
having count(*)>1

-- %%
select AccountID,AccountPrimaryNm,AccountAddressId,AccountCityNm,AcctStateProvinceCd,AccountCountryAlpha2Cd from silverzone.dimcustomermaster where AccountID = '0059446214'select 
* 
from 
silverzone.logsourcefilesprocessed 
where SourceFileName = 'DeviceTwin_20230513.json'
and LogFileStatus = 'Succeeded'
order by CreatedDt desc

-- %%
select * from Silverzone.dimalignmentdata where AccountID in ('0059446214')

-- %% [markdown]
-- # Device Twin

-- %%
select 
* 
from 
silverzone.logsourcefilesprocessed 
where SourceFileName = 'DeviceTwin_20230513.json'
and LogFileStatus = 'Succeeded'
order by CreatedDt desc

-- %%
select count(DeviceID) from silverzone.factdevicetwin where FileNameUUID = 'b4491767-f5f1-446c-84ae-886001663b28'

-- %%
select
deviceid, count(1) as dup_count
from
silverzone.factdevicetwin
group by deviceid
having count(1) > 1

-- %%
select * from silverzone.factdevicetwin where DeviceId = 'CT4F1931101039'

-- %% [markdown]
-- # SYS Logs

-- %%
select * from silverzone.logsourcefilesprocessed L 
where FileNameMessageTypeCd = 'SYS' and L.CreatedBy = 'InitialDataLoad' 
and L.InternalSerialNbr = 'CS4M2127801035'
and L.ExternalSerialNbr = 'D012021316016'
and FileNameUUID in ('9A146B8B-D983-4574-8298-991970095089','5C0044E3-893B-426F-9253-F205256EFC13')
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID in ('9A146B8B-D983-4574-8298-991970095089','5C0044E3-893B-426F-9253-F205256EFC13')

-- %%
select * from silverzone.factalllogs 
--where  
--FileNameUUID = 'FD790560-8E31-4C9C-A9F7-D4AA98096BB3'

-- %%
select * from silverzone.FACTSYSLogs where InternalSerialNbr = 'CS4M2127801035'

-- %%
SELECT 
upper(ExternalSerialNbr), upper(InternalSerialNbr),HdrDataContractNbr, COUNT(*) 
FROM SILVERZONE.FACTSYSLOGS 
GROUP BY upper(ExternalSerialNbr), upper(InternalSerialNbr),HdrDataContractNbr 
HAVING COUNT(*) > 1

-- %% [markdown]
-- # UL Logs and Associations

-- %%
select * from silverzone.logsourcefilesprocessed L where L.FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
select
CycleID,InternalSerialNbr, ExternalSerialNbr,HdrStartTimeGeneratedTmstmp, CardSPSerialNbr,CurrentCycleNbr, count(*)
from silverzone.factullogs
group by CycleID,InternalSerialNbr, ExternalSerialNbr,HdrStartTimeGeneratedTmstmp, CardSPSerialNbr,CurrentCycleNbr
having count(*) > 1

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
select * from silverzone.factalllogs 
--where FileNameUUID = '3e695a7d-86b1-48a6-9abe-4ef50ef7d0f2'

-- %%
--2023-05-12T11:09:58.957+0000
select 
*  
from silverzone.factullogs where 
SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95' and FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
select distinct
	EM1.SerialNumberNbr as CARD_SerialNumberNbr,EM1.ShipStartDt,EM1.ShipEndDt,EM1.MaterialCd as EQUIPCardPartNbr,
	EM2.SerialNumberNbr as DEVICE_SerialNumberNbr,EM2.ShipStartDt,EM2.ShipEndDt,EM2.SoldToID,EM2.shipToID
	from silverzone.logsourcefilesprocessed L 
	left join silverzone.DIMEquipmentMaster EM1 on EM1.SerialNumberNbr = 'CSC2021230DB100162' AND '2022-06-22' BETWEEN EM1.ShipStartDt AND EM1.ShipEndDt
	and EM1.EquipmentTransitStatusNm = 'SHIPPED' 
	left join silverzone.DIMEquipmentMaster EM2 on EM2.SerialNumberNbr = 'D012020149007' AND '2022-06-22' BETWEEN EM2.ShipStartDt AND EM2.ShipEndDt
	and EM2.EquipmentTransitStatusNm = 'SHIPPED'

-- %%
--UnqCyclSeq
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021230DB100162' and CurrentCycleNbr = 31 and HdrAppHeadNbr = 2 -- = 1
--DupCyclDateSeq
union all
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021230DB100162' and CurrentCycleNbr = 31 and HdrAppHeadNbr = 2 and HdrStartDateGeneratedDt = '2022-06-22'-- = 1
union all
--DupCyclUPMSeq
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021230DB100162' and CurrentCycleNbr = 31 and HdrAppHeadNbr = 2 and InternalSerialNbr = 'CS4M2014701012' and ExternalSerialNbr = 'D012020149007'-- = 1
union all
--DupCyclDateUPMSeq
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021230DB100162' and CurrentCycleNbr = 31 and HdrAppHeadNbr = 2 and HdrStartDateGeneratedDt = '2022-06-22' and InternalSerialNbr = 'CS4M2014701012' and ExternalSerialNbr = 'D012020149007'-- = 1

-- %%
-- MsrmntLogTreatmentFileURLTxt - give mlt file name in log processed and match path with that
select SourceFilePath,* from silverzone.logsourcefilesprocessed where SourceFileName like '%COM3_D012020149007_MLT_20220622204220_B%'

-- %%
-- To find ML files before and after this Hdr timestmp ----2023-05-12T11:09:58.957+0000
select 
LFL.FileNameUUID,LFL.LogStartDate,LFL.SourceFilePath,LFL.SourceFileName,LFL.SourceFilePath,* from silverzone.logsourcefilesprocessed LFL 
where LFL.FileNameMessageTypeCd = 'ML'
and LFL.FileNameApplicatorPortCd = 'B'
and LFL.InternalSerialNbr = 'CS3M2021801026' and LFL.ExternalSerialNbr = 'D212020293013'
order by LFL.LogStartDate desc

-- %%
select PreMLFileNameUUID,PreMLSourceFilePath,PreMLSourceFileName,PostMLFileNameUUID,PostMLSourceFileName,PostMLSourceFilePath,Filenameuuid,*
from goldzone.mllogassociation_v WHERE SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95' and FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
select 
FileNameDeviceTypeCd,len(FileNameDtTmstmp), count(*)
from silverzone.logsourcefilesprocessed 
group by FileNameDeviceTypeCd,len(FileNameDtTmstmp)

-- %%
-- To find SYS files before and after this Hdr timestmp --2023-05-12T11:09:58.957+0000
select LFL.FileNameUUID,LFL.LogStartDate,LFL.SourceFilePath,LFL.SourceFileName,LFL.SourceFilePath,* 
from silverzone.logsourcefilesprocessed LFL 
where LFL.FileNameMessageTypeCd = 'SYS'
and upper(LFL.ExternalSerialNbr) = 'D212020293013'
order by LFL.LogStartDate desc

-- %%
select PreSYSFileNameUUID,PreSYSSourceFileName,PreSYSSourceFilePath,PostSYSFileNameUUID,PostSYSSourceFileName,PostSYSSourceFilePath,FileNameUUID,*
from goldzone.syslogassociation_v  
WHERE SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95' and FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
-- To find ASSERT files before and this Hdr timestmp ----2023-05-12T11:09:58.957+0000
 select LFL.FileNameUUID, LFL.LogStartDate,LFL.SourceFilePath,LFL.SourceFileName, * from silverzone.logsourcefilesprocessed LFL 
 where UPPER(LFL.FileNameMessageTypeCd) LIKE '%ASSERT%' and LFL.ExternalSerialNbr = 'D212020293013' 
 order by LFL.LogStartDate desc

-- %%
select PreASSERTFileNameUUID,PreASSERTSourceFileName,PreASSERTSourceFilePath,PostASSERTFileNameUUID,PostASSERTSourceFileName,PostASSERTSourceFilePath,Filenameuuid,* 
from goldzone.assertlogassociation_v WHERE SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95' and FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
-- To find UE files before & after this Hdr timestmp --2023-05-12T11:09:58.957+0000
select HdrTimeGeneratedTmstmp,HdrAppHeadNbr,FileNameUUID,ExternalSerialNbr,InternalSerialNbr, * from silverzone.factuelogs   
where ExternalSerialNbr = 'D212020293013'
and InternalSerialNbr = 'CS3M2021801026'
and FileNameDeviceTypeCd = 'COM3'
and HdrAppHeadNbr in (2,0)
order by HdrTimeGeneratedTmstmp desc

-- %%
select PreUEFileNameUUID,PreUESourceFileName,PreUESourceFilePath,PostUEFileNameUUID,PostUESourceFileName,PostUESourceFilePath,FileNameUUID
from goldzone.uelogassociation_v WHERE SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95' and FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
-- To find UE files before & after this Hdr timestmp --2023-05-12T11:09:58.957+0000
select HdrTimeGeneratedTmstmp,HdrAppHeadNbr,FileNameUUID,ExternalSerialNbr,InternalSerialNbr, * from silverzone.factuelogs   
where ExternalSerialNbr = 'D212020293013'
and InternalSerialNbr = 'CS3M2021801026'
and FileNameDeviceTypeCd = 'COM3'
and HdrAppHeadNbr in (2,0)
order by HdrTimeGeneratedTmstmp desc

-- %%
select EventStartTmstmp,EventEndTmstmp,* from silverzone.factullogs WHERE SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95' and FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %%
select 
TreatmentUEFileNameUUID,TreatmentUESourceFileName,TreatmentUESourceFilePath,*
from goldzone.uelogassociation_v WHERE SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95' and FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'

-- %% [markdown]
-- # Fact All Logs

-- %%
select * from silverzone.factalllogs 
where 
InternalSerialNbr = 'CS4M2301701012' and FileNameMessageTypeCd = 'ENC-Assert'

-- %% [markdown]
-- # Gold zone Log Processed

-- %%
%python
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *
import zipfile
list_f = []
list_s = []

def get_file_list(ls_path):
    for dir_path in dbutils.fs.ls(ls_path):
        if dir_path.isFile():
            list_f.append(dir_path.path)
            list_s.append(dir_path.size)
        elif dir_path.isDir() and ls_path != dir_path.path:
            get_file_list(dir_path.path)
            #list_f.append(get_file_list(dir_path.path))
get_file_list("dbfs:/mnt/raw/DeviceLogs/COM3/CS3M2214401010/IOT/")

cols= ['FilePath','FileSize']
df_list = spark.createDataFrame(zip(list_f, list_s), cols).withColumn('FileName',split(col("FilePath"),'/').getItem(9)).withColumn('Date',split(col("FilePath"),'/').getItem(7)).dropna()

df_list.display()

-- %%
SELECT * FROM cloud_files_state('/mnt/silver/FACTAllLogs/_checkpoints') where path like '%COM3_I212022151002_UE_20230502063723.stx%'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and FileNameMessageTypeCd = 'SYS'
order by CreatedDt desc

-- %%
select FileNameMessageTypeCd, count(1)
from silverzone.logsourcefilesprocessed 
group by FileNameMessageTypeCd

-- %%
%python
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *
import zipfile
list_f = []
list_s = []

def get_file_list(ls_path):
    for dir_path in dbutils.fs.ls(ls_path):
        if dir_path.isFile():
            list_f.append(dir_path.path)
            list_s.append(dir_path.size)
        elif dir_path.isDir() and ls_path != dir_path.path:
            get_file_list(dir_path.path)
            #list_f.append(get_file_list(dir_path.path))
get_file_list("dbfs:/mnt/raw/DeviceLogs/COM3/CS4M2123001010/IOT/20230511/")

cols= ['FilePath','FileSize']
target_df = spark.createDataFrame(zip(list_f, list_s), cols).withColumn('FileName',split(col("FilePath"),'/').getItem(9)).withColumn('Date',split(col("FilePath"),'/').getItem(7)).dropna()

display(target_df.count())
target_df.orderBy(col("Date"),col("FileName"),col("FileSize")).display()

-- %%
%python
target_df.createOrReplaceTempView("target_df")

-- %%
-- select 
-- FileNameUUID,ExternalSerialNbr,InternalSerialNbr,ConfigId,SourceFilePath,SourceFileName,SourceFileSize,FileNameDeviceTypeCd,FileNameMessageTypeCd,FileNameDtTmstmp,FileNameApplicatorPortCd,FileNameCycleNbr,SourceFileRecordCt,IsLogFileProcessedInd,LogFileStatus,ErrorMessage,CreatedBy,CreatedDt,UpdatedBy,UpdatedDt,
-- ifnull(LogStartDate, to_timestamp(FileNameDtTmstmp, 'yyyyMMddHHmmss')) AS LogStartDate,ifnull(LogEndDate, to_timestamp(FileNameDtTmstmp, 'yyyyMMddHHmmss')) AS LogEndDate,
-- row_number() OVER(PARTITION BY SourceFileName ORDER BY ifnull(LogEndDate , to_timestamp(FileNameDtTmstmp, 'yyyyMMddHHmmss')) DESC, UpdatedDt DESC) AS UniqueSequence
-- from silverzone.logsourcefilesprocessed where CreatedBy = 'InitialDataLoad' and FileNameDeviceTypeCd in ('COM3') and InternalSerialNbr = 'CS3M2021801026' and SourceFilePath like '%20230512%'
-- minus
--intersect
select 
FileNameUUID,ExternalSerialNbr,InternalSerialNbr,ConfigId,SourceFilePath,SourceFileName,SourceFileURL,SourceFileSize,FileNameDeviceTypeCd,FileNameMessageTypeCd,FileNameDtTmstmp,FileNameApplicatorPortCd,FileNameCycleNbr,SourceFileRecordCt,IsLogFileProcessedInd,LogFileStatus,ErrorMessage,CreatedBy,CreatedDt,UpdatedBy,UpdatedDt,
LogStartDate,LogEndDate,TimeZoneDesc,UniqueSequence
from goldzone.sourcefilespath_v where CreatedBy = 'InitialDataLoad' and FileNameDeviceTypeCd in ('COM3') and InternalSerialNbr = 'CS3M2021801026' and SourceFilePath like '%20230512%'
order by CreatedDt desc

-- %%
select count(*) from silverzone.logsourcefilesprocessed where FileNameDeviceTypeCd in ('COM3','CT') --limit 1

-- %%
select count(*) from goldzone.sourcefilespath_v where FileNameDeviceTypeCd in ('COM3','CT') --limit 1

-- %%
with src as (
Select LF.FileNameUUID,UPPER(LF.ExternalSerialNbr) AS ExternalSerialNbr,UPPER(LF.InternalSerialNbr) AS InternalSerialNbr, ConfigId,SourceFilePath,SourceFileName, CASE WHEN SourceFilePath like 'DeviceLogs%' THEN CONCAT('https://agnadlsg2prodctdatastore.blob.core.windows.net/raw/',LF.SourceFilePath,'?sv=2022-11-02&ss=b&srt=sco&sp=rlx&se=2111-05-12T23:20:41Z&st=2023-05-12T15:20:41Z&spr=https&sig=oqUQXPIurMrs4zyJhk8ZvzvhnS4m3lyZwPUGvVMaT%2Bg%3D') WHEN SourceFilePath like 'com1archive2010-2015%' THEN CONCAT('https://agnstgprodcom1archive.blob.core.windows.net/com1archive2010-2015/',LF.SourceFilePath,'?sv=2021-10-04&ss=b&srt=sco&st=2023-05-11T16%3A51%3A34Z&se=2024-05-12T16%3A51%3A00Z&sp=rl&sig=RpMoyfZpsM8PXClxtZh2C52dqBVqueh7IKQiNe5YK8U%3D') ELSE CONCAT('https://agnstgprodcoolsculptiot.blob.core.windows.net/',LF.SourceFilePath,'?sv=2021-10-04&ss=b&srt=sco&st=2023-05-09T20%3A14%3A21Z&se=2024-05-10T20%3A14%3A00Z&sp=rl&sig=bczSgz%2BXwOgpICSjGGb%2FRNosgC3iD%2BeE7ZWzOUKfwhA%3D') END AS SourceFileURL, SourceFileSize, FileNameDeviceTypeCd,FileNameMessageTypeCd, replace(FileNameDtTmstmp,'.csv','') AS FileNameDtTmstmp, FileNameApplicatorPortCd,FileNameCycleNbr, SourceFileRecordCt,IsLogFileProcessedInd,LogFileStatus,ErrorMessage,LF.CreatedBy,LF.CreatedDt,LF.UpdatedBy,LF.UpdatedDt, CASE WHEN FileNameDeviceTypeCd = 'COM1' THEN LogStartDate ELSE ifnull(LogStartDate, to_timestamp(FileNameDtTmstmp, 'yyyyMMddHHmmss')) END AS LogStartDate, CASE WHEN FileNameDeviceTypeCd = 'COM1' THEN LogEndDate ELSE ifnull(LogEndDate, to_timestamp(FileNameDtTmstmp, 'yyyyMMddHHmmss')) END AS LogEndDate, DSE.TimeZoneDesc, row_number() OVER(PARTITION BY LF.SourceFileName ORDER BY CASE WHEN FileNameDeviceTypeCd = 'COM1' THEN LogStartDate ELSE ifnull(LogStartDate, to_timestamp(FileNameDtTmstmp, 'yyyyMMddHHmmss')) END DESC, LF.UpdatedDt DESC) AS UniqueSequence FROM silverzone.LogSourceFilesProcessed AS LF LEFT JOIN silverzone.dimstartendparameter AS DSE ON LF.FileNameUUID = DSE.FileNameUUID)
select * from src where FileNameDeviceTypeCd in ('COM3','CT')
--minus
intersect
select * from goldzone.sourcefilespath_v where FileNameDeviceTypeCd in ('COM3','CT')

-- %% [markdown]
-- # Gold zone Fact Cycle

-- %%
-- TC1
select * from silverzone.logsourcefilesprocessed L where FileNameDeviceTypeCd = 'COM3' and FileNameMessageTypeCd = 'UL' and L.CreatedBy = 'InitialDataLoad' 
and L.SourceFileName = '20230512130141_COM3_D212020293013_UL_20230512110958_B_95'
order by CreatedDt desc

-- %%
SELECT
cyc.cycleid,
cast(date_format(cyc.EventStartTmstmp,'yyyy-MM-dd HH:mm:ss') as TIMESTAMP) as BeginTime,
cast(date_format(cyc.EventEndTmstmp ,'yyyy-MM-dd HH:mm:ss') as TIMESTAMP) as EndTime,
CYC.InternalSerialNbr AS SBC_sn, CYC.InternalSerialNbr, CYC.HdrAppHeadNbr, 
ifnull(CYC.Applicator1SerialNbr,CYC.ApplicatorSerialNbr) as Applicator_sn, 
CYC.ApplicatorInternalSerialNbr as APP_sn, CYC.ApplicatorConfigurantionNbr as ssAPPident, CYC.CardSPSerialNbr as EZCard, CYC.CurrentCycleNbr as CyclesLeft, CYC.CycleFinalStatusReasonDesc as Status, ifnull(CYC.SwVersionNbr,SBCVersionNbr) as ssWinCE, CYC.InterruptStart, CYC.CycleFinalStatusReasonDesc as InterruptStatus, ifnull(CYC.CycleErrorCd,CYC.CycleErrorZCd) as InterruptError, 
CYC.PatientNextSameFlg as SameNextPatient, CYC.PatientNewFlg as ReturningPatient, CYC.PatientGenderCd as PatientType, CYC.PatientBodyPartNm as TreatmentBodyPart, 
CYC.BrilliantDistinctionID as CoolSculptingID2, CYC.CoolSculptingID, CYC.ExternalSerialNbr as UpperModuleNumber, CYC.FileNameDeviceTypeCd as ProductTypeCd, 
CYC.Applicator2SerialNbr, CYC.MaxCoolTmp, CYC.MaxApplicator1Tmp, CYC.MaxApplicator2Tmp, CYC.TtlTrtmntDurationTm, CYC.TrtmntPrtclCd, CYC.ChsnTrtmntDurationTm, 
CYC.BDIDEncryptdFlg AS AlleIDEncryptedFlg, CYC.AlleIDDecryptedFlg, AppVer.ApplicatorFrndlyNm, Appver.ApplicatorEngnrNm, CYC.AlleCertDt, CYC.FileNameUUID, 
CYC.CreatedBy, CYC.CreatedDt, CYC.UpdatedBy, CYC.UpdatedDt 
FROM Silverzone.FACTULLogs CYC 
LEFT JOIN Silverzone.DIMApplicatorVerCd AppVer ON AppVer.SSAPPIdentID = Left(CYC.ApplicatorConfigurantionNbr,7) 
Where CYC.CycleUsedCnt = 1 and CYC.ExternalSerialNbr <> 'Unkonwn' and CYC.EventStartTmstmp is not Null 
--minus
intersect
select * from goldzone.cyclesdata_v

-- %%
select * from silverzone.factullogs where 
--FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED'
CycleID = '3000417'

-- %%
select * from goldzone.cyclesdata_v where 
--FileNameUUID = '87A51EA2-6574-49F1-B6A7-6203118592ED' 
CycleID = '3000417'

-- %%
select * from goldzone.cyclesdata_v where EZCard is null

-- %%
select 
CycleID,BeginTime, count(*) 
from goldzone.cyclesdata_v 
group by CycleID, BeginTime 
having count(*) > 1

-- %% [markdown]
-- # Gold zone Sys Device Twin

-- %%
select * from silverzone.factsyslogs where InternalSerialNbr = 'CS4M2007301004' and ExternalSerialNbr = 'D012020170008'

-- %%
select * from silverzone.factdevicetwin where InternalSerialNbr = 'CS4M2007301004' and ExternalSerialNbr = 'D012020170008'

-- %%
select * from goldzone.Device_v where InternalSerialNbr = 'CS4M2007301004' and ExternalSerialNbr = 'D012020170008'

-- %%
SELECT
upper(InternalSerialNbr),upper(ExternalSerialNbr), COUNT(*)
FROM
goldzone.Device_v
group by upper(InternalSerialNbr),upper(ExternalSerialNbr)
having count(*) > 1

-- %% [markdown]
-- # Read IOT files from Raw zone storage explorer

-- %%
%python
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *
import zipfile
list_f = []
list_s = []

def get_file_list(ls_path):
    for dir_path in dbutils.fs.ls(ls_path):
        if dir_path.isFile():
            list_f.append(dir_path.path)
            list_s.append(dir_path.size)
        elif dir_path.isDir() and ls_path != dir_path.path:
            get_file_list(dir_path.path)
            #list_f.append(get_file_list(dir_path.path))
get_file_list("dbfs:/mnt/raw/DeviceLogs/COM3/CS3M2214401010/IOT/")

cols= ['FilePath','FileSize']
df_list = spark.createDataFrame(zip(list_f, list_s), cols).withColumn('FileName',split(col("FilePath"),'/').getItem(9)).withColumn('Date',split(col("FilePath"),'/').getItem(7)).dropna()

df_list.display()

-- %% [markdown]
-- # Read USB files from Raw zone storage explorer

-- %%
%python
list_f = []
list_s = []
def get_file_list(ls_path):
    for dir_path in dbutils.fs.ls(ls_path):
        if dir_path.isFile():
            list_f.append(dir_path.path)
            list_s.append(dir_path.size)
        elif dir_path.isDir() and ls_path != dir_path.path:
            get_file_list(dir_path.path)
get_file_list("dbfs:/mnt/raw/DeviceLogs/COM3/CS3M2019001002/USB/")

cols= ['FilePath','FileSize']
df_list = spark.createDataFrame(zip(list_f, list_s), cols).withColumn('FileName',split(col("FilePath"),'/').getItem(9)).withColumn('Date',split(col("FilePath"),'/').getItem(7)).dropna()
df_list.display()

-- %% [markdown]
-- #Customer master logic

-- %%
Union of ZHCUSTOMR file data and ZBWI05225_CUSTOMER_AGN_CON file data
No update on existing records only insert this is as per the existing logic currently in production
AccountPrimaryNm should not be null
If there is more than one accountid after union then this row number or rank logic is applied to load : accountid order by accountid desc,ProcessedByNm desc, accountcitynm desc, accountcity2nm desc

-- %% [markdown]
-- #Product Hierarchy logic

-- %%
Union of PROD_CLASS file data and ZBWI05306_COOLCONNECT_PRODCLASS file data
Filter in PROD_CLASS file alone where ProductCategoryCd >= 2400 and ProductCategoryCd <2500
If there is more than one productcd after union then this row number or rank logic is applied to load : 
w=Window.partitionBy("ProductCd").orderBy(desc("DistributionChannelCd"),desc("ProductCd"),desc("ProductDesc"),desc("ProductCategoryCd"),desc("ProductCategoryNm"),desc("ProductLineCd"))

-- %% [markdown]
-- # Equipment master logic

-- %%
Union of ZLTQ_EQUIPMENT_MASTER_* and ZBWI05226_AGN_CON_LA_*
Join to silverzone.DIMProductHierarchy using ProductCd to get value in MaterialCd column
column "INVENTORYMOVEMENTSTATUSDESC" should have value "Returned" and value in ReturnDt column should be same as value in ShipStartDt when the previous transaction status is "SHIPPED" and current transaction status is "IN WAREHOUSE"

-- %% [markdown]
-- #PDM Alignment logic

-- %%
Records having TERRITORY_CODE starting like 'CP' are alone considered
When we have duplicate accountid in file then we consider the row having minimum of TERRITORY_CODE 
Left join to customer master silverzone table on accountid column
make sure you have CUSTOMER_ID in silverzone.dimcustomermaster table so that the data is populated in these columns in target table : AccountPrimaryNm, AccountAddressId, AccountCityNm, AcctStateProvinceCd, AccountCountryAlpha2Cd

-- %% [markdown]
-- # Device Twin logic

-- %%
It is a huge nested json file it will be difficult to even scroll through the file.
If you want to test pick up any random device id and Take a copy of the file
Open the file and Search the device id
Delete content before the device id starting portion and Copy that device id data
Format the json to readable one and Compare the data between file to table
It is direct one to one mapping and there is no transformation
Validate logic when there are both software version and version under reported : when softwareversion value is null then version value is picked and not null then softwareVersion value is picked 
and loaded to target table
Above logic is for columns starting from App1Version till Vac2Version

-- %% [markdown]
-- # Start End Parameter Logic

-- %%
For all the log files there will be two contract numbers in file. One is 14020 and 14023. 
14020 - Start parameter
14023 - End parameter
We will load the data (data in curly braces) of these contract numbers from file to this table

-- %% [markdown]
-- # Fact All Logs logic

-- %%
For all assert log type files the table has data for contracts : 14020 and 14023 from file
For other log types whole json file data is displayed in table

-- %% [markdown]
-- # SYS Logs logic

-- %%
We are processing 4 contract numbers from file, those are 21062, 15039, 15024 and 15008
Logic is we will populate the sys log like for each external serial number there will be only one record of these 4 contracts (if all contracts are available for that device otherwise whatever contract is available that will be shown)
Always for any contract the data will be populated based on the latest HdrTimeGeneratedTmstmp. Suppose the file got more than one row of same contract then which row has latest timestamp that will be picked and loaded to table

-- %% [markdown]
-- # COM3 UL Logic for columns

-- %%
--COM3 UL
--Mapping : 
		Until BrilliantDistinctionID column it is direct mapping to file (values will be directly in file)
		BDIDEncryptdFlg , alleCertDate , MsrmntLogTreatmentFileNm it is direct mapping to file (values will be directly in file)
		CycleFinalStatusReasonDesc and CycleFinalStatusDesc it is direct mapping to file (values will be directly in file)

		--EM Derived columns logic:
		Take CardSPSerialNbr value and input as EM1.SerialNumberNbr value and externalserialnumber 
     value and input as EM2.SerialNumberNbr and HdrStartDateGeneratedDt value for date clause
     and execute below query to validate EQUIPCardPartNbr , SoldToAccountID and ShipToAccountID

		 -- To get CoolsculptingID
		 To validate CoolSculptingID column if we have bd value in file i.e True value in isBDNumberEncrypted field in file ,
       connect to prod db and enter brilliant distinction id in file in where clause 
		of below query and compare data in Coolsculptingid column with coolsculpting id in fact ul logs table
		select * from [dbo].[F_zm_Cycle]
		where CoolSculptingID2 = ''
     If we dont have bd value then use below logic and validate
		'BDIDEncryptdFlg'!='True' then "CoolSculptingID" , 
			when(col('BDIDEncryptdFlg') == "False" then col('BrilliantDistinctionID'))
            when(col('BDIDEncryptdFlg').isNull() ,lit(None))
            otherwise(col('BrilliantDistinctionID'))))  

--11. To validate AlleIDDecryptedFlg use below logic and validate
				AlleIDDecryptedFlg, when(col('BDIDEncryptdFlg') == "True","True")
                                 .when(col('BDIDEncryptdFlg') == "False",lit(None))
                                 .otherwise(lit(None))))

--12. To validate SmartCardShippedInd, CoolDeviceShippedInd, SoldToAccountID and ShipToAccountID use below logic and validate
				'SmartCardShippedInd',when(col('CARD_SerialNumberNbr').isNull(),0).otherwise(1)) - EM1 table
				'CoolDeviceShippedInd',when(col('DEVICE_SerialNumberNbr').isNull(),0).otherwise(1)) - EM2 table
				"SoldToAccountID",when(col('DEVICE.SoldToID').isNull(),'0000000000').otherwise(col('DEVICE.SoldToID')))- EM2 table
				"ShipToAccountID",when(col('DEVICE.shipToID').isNull(),'0000000000').otherwise(col('DEVICE.shipToID')))- EM2 table

--13. To validate UnsoldFraudFlg, DuplicateCycleFlg, CycleUtilizationFraudFlg, CycleUsedCnt use below logic and validate				
				"UnsoldFraudFlg",when((col('SmartCardShippedInd') + col('CoolDeviceShippedInd'))== 2,"N").otherwise("Y"))
                "DuplicateCycleFlg",when(col('UnqCyclSeq')== 1,"N").otherwise("Y"))
                "CycleUtilizantionFraudFlg",when((col('UnqCyclSeq') + col('DupCyclDateUPMSeq'))== 2,"N").otherwise("Y"))
                "CycleUsedCnt",when(col('DupCyclDateUPMSeq')== 1,1).otherwise(0))
                "IsFraudCycleFlg",when((col("UnsoldFraudFlg")=="N") & (col("CycleUtilizantionFraudFlg")=="N"),"N").otherwise("Y"))
				'CompletedCycleUsedCnt',when(col("CycleFinalStatusDesc")=="Completed",1).otherwise(0))
				SmartCardShipDt = col("CARD.ShipStartDt").alias("SmartCardShipDt") - EM1 table

-- %% [markdown]
-- # CT UL Logic for columns

-- %%
--6. Mapping for CT columns: 
		From HdrFormatVersionCd to EventEndTmstmp it is direct mapping to file (values will be directly in file)
		CardSPSerialNbr , PrevCTCnt, CurrentCycleNbr, PatientNextSameFlg to BrilliantDistinctionID it is direct mapping to file (values will be directly in file)
		From CycleStartDt to TrtmntPrtclCd it is direct mapping to file (values will be directly in file)
		From CycleFinalStatusReasonDesc to TtlTrtmntDurationTm it is direct mapping to file (values will be directly in file)

		-- EM Columns Logic

		Take CardSPSerialNbr value and input as EM1.SerialNumberNbr value and externalserialnumber 
     value and input as EM2.SerialNumberNbr and HdrStartDateGeneratedDt value for date clause
     and execute below query to validate EQUIPCardPartNbr , SoldToAccountID and ShipToAccountID

		 -- 10. To validate CoolSculptingID column based on bdsn column in the file,
       'BrilliantDistinctionID'=="Unknown"|'BrilliantDistinctionID'.isNull()
                  .withColumn("CoolSculptingID",when(col('BrilliantDistinctionID') == "Unknown",lit(None))
                              .otherwise("Unknown")))
        'BrilliantDistinctionID'!="Unknown"&'BrilliantDistinctionID'.isNotNull()
                   .withColumn("CoolSculptingID",rsa_decrypt_udf(col('BrilliantDistinctionID')))) 

--11. To validate BDIDEncryptdFlg column based on CoolSculptingID column derived in above step,
       "BDIDEncryptdFlg", when(col('CoolSculptingID').isNull() ,lit(None))
                                                .otherwise("True")

-- 12. To validate AlleIDDecryptedFlg column based on BDIDEncryptdFlg column derived in above step,
       AlleIDDecryptedFlg, when(col('BDIDEncryptdFlg').isNull() ,lit(None))
                                                .otherwise("True")
				   
--12. To validate SmartCardShippedInd, CoolDeviceShippedInd, SoldToAccountID and ShipToAccountID use below logic and validate

				'SmartCardShippedInd',when(col('CARD_SerialNumberNbr').isNull(),0).otherwise(1)) - EM1 table
				'CoolDeviceShippedInd',when(col('DEVICE_SerialNumberNbr').isNull(),0).otherwise(1)) - EM2 table
				"SoldToAccountID",when(col('DEVICE.SoldToID').isNull(),'0000000000').otherwise(col('DEVICE.SoldToID')))- EM2 table
				"ShipToAccountID",when(col('DEVICE.shipToID').isNull(),'0000000000').otherwise(col('DEVICE.shipToID')))- EM2 table

--13. To validate UnsoldFraudFlg, DuplicateCycleFlg, CycleUtilizationFraudFlg, CycleUsedCnt use below logic and validate				
				"UnsoldFraudFlg",when((col('SmartCardShippedInd') + col('CoolDeviceShippedInd'))== 2,"N").otherwise("Y"))
                "DuplicateCycleFlg",when(col('UnqCyclSeq')== 1,"N").otherwise("Y"))
                "CycleUtilizantionFraudFlg",when((col('UnqCyclSeq') + col('DupCyclDateUPMSeq'))== 2,"N").otherwise("Y"))
                "CycleUsedCnt",when(col('DupCyclDateUPMSeq')== 1,1).otherwise(0))
                "IsFraudCycleFlg",when((col("UnsoldFraudFlg")=="N") & (col("CycleUtilizantionFraudFlg")=="N"),"N").otherwise("Y"))
				'CompletedCycleUsedCnt',when(col("CycleFinalStatusDesc")=="Completed",1).otherwise(0))
				SmartCardShipDt = col("CARD.ShipStartDt").alias("SmartCardShipDt") - EM1 table

-- %% [markdown]
-- # Gold zone log processed logic

-- %%
Logic for goldzonelogsourcefilesprocessed , it is a view created on top of silver zone logsourcefilesprocessed. See the validation code above

-- %% [markdown]
-- # Fact Cycle logic

-- %%
Logic for goldzone factcycle , it is a view created from 
Silverzone.FACTULLogs CYC 
LEFT JOIN Silverzone.DIMApplicatorVerCd AppVer ON AppVer.SSAPPIdentID = Left(CYC.ApplicatorConfigurantionNbr,7) 
Where CYC.CycleUsedCnt = 1 and CYC.ExternalSerialNbr <> 'Unkonwn' and CYC.EventStartTmstmp is not Null

-- %% [markdown]
-- # Gold zone sys device twin view logic (goldzone.device_v)

-- %%
For each device we see sys log information and devicetwin information in a single row. 
Logic for HdrTimeGeneratedTmstmp will be the max of all 4 contract numbers from sys logs

-- %% [markdown]
-- # Incremental load testing for a COM3 device

-- %%
%python
from pyspark.sql.functions import *
from pyspark.sql.types import *
from delta.tables import *
import zipfile
list_f = []
list_s = []

def get_file_list(ls_path):
    for dir_path in dbutils.fs.ls(ls_path):
        if dir_path.isFile():
            list_f.append(dir_path.path)
            list_s.append(dir_path.size)
        elif dir_path.isDir() and ls_path != dir_path.path:
            get_file_list(dir_path.path)
            #list_f.append(get_file_list(dir_path.path))
get_file_list("dbfs:/mnt/raw/DeviceLogs/COM3/CS3M2214401010/IOT/")

cols= ['FilePath','FileSize']
df_list = spark.createDataFrame(zip(list_f, list_s), cols).withColumn('FileName',split(col("FilePath"),'/').getItem(9)).withColumn('Date',split(col("FilePath"),'/').getItem(7)).dropna()

df_list.display()

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_Configurator-Assert_20230513082725.txt'
--and FileNameMessageTypeCd = 'SYS'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = 'cdc49d3a-d9e9-4fa8-8753-5d38b6c378a9'

-- %%
select * from silverzone.factalllogs where FileNameUUID = 'cdc49d3a-d9e9-4fa8-8753-5d38b6c378a9'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_ENC-Assert_20230513082725.txt'
--and FileNameMessageTypeCd = 'SYS'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = 'efa0550b-d964-484d-9571-6b30549ea7f7'

-- %%
select * from silverzone.factalllogs where FileNameUUID = 'efa0550b-d964-484d-9571-6b30549ea7f7'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_Installer-Assert_20230513082725.txt'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '510f9ae2-2cac-4649-a48f-dc7c7fdabd3f'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '510f9ae2-2cac-4649-a48f-dc7c7fdabd3f'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_LogExtractor-Assert_20230513082725.txt'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '23a1cfda-07e1-442f-873d-93f9de658402'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '23a1cfda-07e1-442f-873d-93f9de658402'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_LogSVC-Assert_20230513082725.txt'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '1bf69dff-2722-4129-83bb-6885a272d93d'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '1bf69dff-2722-4129-83bb-6885a272d93d'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_MedApp-Assert_20230513082725.txt'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = 'cc52e0dd-bc3e-499e-8ddb-44ab29f7f54b'

-- %%
select * from silverzone.factalllogs where FileNameUUID = 'cc52e0dd-bc3e-499e-8ddb-44ab29f7f54b'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_MedAppPassThru-Assert_20230513082725.txt'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '2e0d1a69-3f19-4d30-9cd5-f904e28ca6b5'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '2e0d1a69-3f19-4d30-9cd5-f904e28ca6b5'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_MedAppUI-Assert_20230513082725.txt'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = 'ea89c19b-8967-4ba1-89f1-18f082e94f3a'

-- %%
select * from silverzone.factalllogs where FileNameUUID = 'ea89c19b-8967-4ba1-89f1-18f082e94f3a'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_PsbHubService-Assert_20230513082725.txt'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '6790712d-ae20-4178-be49-f86915ed89f8'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '6790712d-ae20-4178-be49-f86915ed89f8'

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_SYS_20230507031331.stx'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '908d392e-fad0-4325-93c0-ea097b2a97de'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '0fd4bf08-7162-41db-b783-5bdbc3145e10'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '0fd4bf08-7162-41db-b783-5bdbc3145e10' and HdrDataContractNbr in (14020,21062,15024,15039,14023) order by HdrTimeGeneratedTmstmp asc

-- %%
select * from silverzone.factalllogs where FileNameUUID = '0fd4bf08-7162-41db-b783-5bdbc3145e10' and HdrDataContractNbr in (15008) order by HdrTimeGeneratedTmstmp desc limit 1

-- %%
select * from silverzone.factsyslogs where SourceFileName = 'COM3_I212022151002_SYS_20230507031331.stx' order by HdrTimeGeneratedTmstmp asc

-- %%
select * from silverzone.logsourcefilesprocessed  
where FileNameDeviceTypeCd in ('COM3','CT')	
and CreatedBy <> 'InitialDataLoad'
and InternalSerialNbr = 'CS3M2214401010'
and LogFileStatus = 'Succeeded'
and sourcefilename = 'COM3_I212022151002_UL_20230513084328_A_17.stx'
order by CreatedDt desc

-- %%
select * from silverzone.dimstartendparameter where FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
select * from silverzone.factalllogs where FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
select * from silverzone.factullogs where FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
select distinct
	EM1.SerialNumberNbr as CARD_SerialNumberNbr,EM1.ShipStartDt,EM1.ShipEndDt,EM1.MaterialCd as EQUIPCardPartNbr,
	EM2.SerialNumberNbr as DEVICE_SerialNumberNbr,EM2.ShipStartDt,EM2.ShipEndDt,EM2.SoldToID,EM2.shipToID
	from silverzone.logsourcefilesprocessed L 
	left join silverzone.DIMEquipmentMaster EM1 on EM1.SerialNumberNbr = 'CSC2021174DB101090' AND '2023-05-13' BETWEEN EM1.ShipStartDt AND EM1.ShipEndDt
	and EM1.EquipmentTransitStatusNm = 'SHIPPED' 
	left join silverzone.DIMEquipmentMaster EM2 on EM2.SerialNumberNbr = 'I212022151002' AND '2023-05-13' BETWEEN EM2.ShipStartDt AND EM2.ShipEndDt
	and EM2.EquipmentTransitStatusNm = 'SHIPPED'

-- %%
--UnqCyclSeq
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021174DB101090' and CurrentCycleNbr = 17 and HdrAppHeadNbr = 1 -- = 1
--DupCyclDateSeq
union all
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021174DB101090' and CurrentCycleNbr = 17 and HdrAppHeadNbr = 1 and HdrStartDateGeneratedDt = '2023-05-13'-- = 1
union all
--DupCyclUPMSeq
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021174DB101090' and CurrentCycleNbr = 17 and HdrAppHeadNbr = 1 and InternalSerialNbr = 'CS3M2214401010' and ExternalSerialNbr = 'I212022151002'-- = 1
union all
--DupCyclDateUPMSeq
select * from silverzone.FACTULLogs where CardSPSerialNbr = 'CSC2021174DB101090' and CurrentCycleNbr = 17 and HdrAppHeadNbr = 1 and HdrStartDateGeneratedDt = '2023-05-13' and InternalSerialNbr = 'CS3M2214401010' and ExternalSerialNbr = 'I212022151002'-- = 1

-- %%
-- MsrmntLogTreatmentFileURLTxt - give mlt file name in log processed and match path with that
select SourceFilePath,* from silverzone.logsourcefilesprocessed where SourceFileName like '%COM3_I212022151002_MLT_20230513084103_A%'

-- %%
-- To find ML files before and after this Hdr timestmp 2023-05-13T08:43:28.205+0000
select 
LFL.FileNameUUID,LFL.LogStartDate,LFL.SourceFilePath,LFL.SourceFileName,LFL.SourceFilePath,* from silverzone.logsourcefilesprocessed LFL 
where LFL.FileNameMessageTypeCd = 'ML'
and LFL.FileNameApplicatorPortCd = 'A'
and upper(LFL.InternalSerialNbr) = 'CS3M2214401010' and upper(LFL.ExternalSerialNbr) = 'I212022151002'
order by LFL.LogStartDate desc

-- %%
select PreMLFileNameUUID,PreMLSourceFilePath,PreMLSourceFileName,PostMLFileNameUUID,PostMLSourceFileName,PostMLSourceFilePath,Filenameuuid,*
from goldzone.mllogassociation_v WHERE 
SourceFileName = 'COM3_I212022151002_UL_20230513084328_A_17.stx' and FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
-- To find SYS files before and after this Hdr timestmp 2023-05-13T08:43:28.205+0000
select LFL.FileNameUUID,LFL.LogStartDate,LFL.SourceFilePath,LFL.SourceFileName,LFL.SourceFilePath,* 
from silverzone.logsourcefilesprocessed LFL 
where LFL.FileNameMessageTypeCd = 'SYS'
and upper(LFL.ExternalSerialNbr) = 'I212022151002'
order by LFL.LogStartDate desc

-- %%
select PreSYSFileNameUUID,PreSYSSourceFileName,PreSYSSourceFilePath,PostSYSFileNameUUID,PostSYSSourceFileName,PostSYSSourceFilePath,FileNameUUID,*
from goldzone.syslogassociation_v  where
SourceFileName = 'COM3_I212022151002_UL_20230513084328_A_17.stx' and FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
-- To find ASSERT files before and this Hdr timestmp 2023-05-13T08:43:28.205+0000
 select LFL.FileNameUUID, LFL.LogStartDate,LFL.SourceFilePath,LFL.SourceFileName, * from silverzone.logsourcefilesprocessed LFL 
 where UPPER(LFL.FileNameMessageTypeCd) LIKE '%ASSERT%' and upper(LFL.ExternalSerialNbr) = 'I212022151002'
 order by LFL.LogStartDate desc

-- %%
select PreASSERTFileNameUUID,PreASSERTSourceFileName,PreASSERTSourceFilePath,PostASSERTFileNameUUID,PostASSERTSourceFileName,PostASSERTSourceFilePath,Filenameuuid,* 
from goldzone.assertlogassociation_v WHERE 
SourceFileName = 'COM3_I212022151002_UL_20230513084328_A_17.stx' and FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
-- To find UE files before & after this Hdr timestmp 2023-05-13T08:43:28.205+0000
select HdrTimeGeneratedTmstmp,HdrAppHeadNbr,FileNameUUID,ExternalSerialNbr,InternalSerialNbr, * from silverzone.factuelogs ue  
where upper(ue.InternalSerialNbr) = 'CS3M2214401010' and upper(ue.ExternalSerialNbr) = 'I212022151002'
and FileNameDeviceTypeCd = 'COM3'
--and HdrAppHeadNbr in (2,0)
order by HdrTimeGeneratedTmstmp desc

-- %%
select PreUEFileNameUUID,PreUESourceFileName,PreUESourceFilePath,PostUEFileNameUUID,PostUESourceFileName,PostUESourceFilePath,FileNameUUID
from goldzone.uelogassociation_v WHERE SourceFileName = 'COM3_I212022151002_UL_20230513084328_A_17.stx' and FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
-- To find UE files before & after this Hdr timestmp --2023-05-12T11:09:58.957+0000
select HdrTimeGeneratedTmstmp,HdrAppHeadNbr,FileNameUUID,ExternalSerialNbr,InternalSerialNbr, * from silverzone.factuelogs ue
where upper(ue.InternalSerialNbr) = 'CS3M2214401010' and upper(ue.ExternalSerialNbr) = 'I212022151002'
and FileNameDeviceTypeCd = 'COM3'
--and HdrAppHeadNbr in (2,0)
order by HdrTimeGeneratedTmstmp desc

-- %%
select EventStartTmstmp,EventEndTmstmp,* from silverzone.factullogs WHERE SourceFileName = 'COM3_I212022151002_UL_20230513084328_A_17.stx' and FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %%
select 
TreatmentUEFileNameUUID,TreatmentUESourceFileName,TreatmentUESourceFilePath,*
from goldzone.uelogassociation_v WHERE SourceFileName = 'COM3_I212022151002_UL_20230513084328_A_17.stx' and FileNameUUID = '13ce261f-8df5-43cb-b586-727203d1e5ec'

-- %% [markdown]
-- #CoolsculptingID comparison with current production , picked randomly 10,014 records

-- %%
select * from silverzone.factullogs where FileNameDeviceTypeCd in ('COM3','CT')
